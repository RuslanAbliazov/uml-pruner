# %%
import pandas as pd

# %%
data = pd.read_csv("annotations.csv")

# %%
data = data[data["annotator"] == "RuslanAbliazov"]
data = data[["central_node", "query", "entity_annotations"]]
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#                                         central_node  \
# 0  org.apache.hadoop.yarn.server.nodemanager.Wind...
# 1  ghidra.app.plugin.core.function.tags.FunctionT...
# 2  ghidra.program.model.address.AddressSetViewAda...
# 3  org.apache.flink.runtime.jobmaster.slotpool.Bl...
# 4  ghidra.framework.main.projectdata.actions.Find...
#
#                                                query  \
# 0  Show the main and supporting classes involved ...
# 1  Show the main and supporting classes involved ...
# 2  Show the main and supporting classes involved ...
# 3  Show the main and supporting classes responsib...
# 4  Show the main and supporting classes responsib...
#
#                                   entity_annotations
# 0  {"org.apache.hadoop.fs.Path": "useful", "org.a...
# 1  {"ghidra.app.plugin.core.function.tags.Functio...
# 2  {"ghidra.program.model.address.AddressSet": "r...
# 3  {"org.apache.flink.runtime.jobmaster.slotpool....
# 4  {"ghidra.framework.main.FrontEndPlugin": "requ...

# %%
data.to_csv("validation_dataset.csv")
